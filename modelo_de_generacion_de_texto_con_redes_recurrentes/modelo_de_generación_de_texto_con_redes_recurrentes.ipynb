# %% [markdown]
# <img src="imagenes/rn3.png" width="200">
# <img src="http://www.identidadbuho.uson.mx/assets/letragrama-rgb-150.jpg" width="200">

# %% [markdown]
# # [Curso de Redes Neuronales](https://curso-redes-neuronales-unison.github.io/Temario/)
#
# # Redes recurrentes, implementación simple
#
# [**Julio Waissman Vilanova**](http://mat.uson.mx/~juliowaissman/), 9 de mayo de 2018.
#
# En esta libreta vamos a explorar como desarrollar redes recurrentes, simples y basadas en unidades de memoria de largo y corto plazo (LSTM), aplicadas a la generación automática de texto.
#
# Dado que estamos en México en año electoral, y que se vota por diputados y presidentes municipales en muchisimos municipios del país, nos preguntamos si podríamos inventar nuevos municipios para que todos los candidatos tuvieran un lugar que gobernar. Así, generamos una lista con el nombre de todos los municipios de México, y la vamos a usar para aprender los nombres, y generar nombres a partir de una red recurrente. Esto es interesante ya que en México hay muchos municipios cuyos nombres tienen raices del español, el nahuatl, direrentes lenguas mayas, varias lenguas de la familia yuto-azteca, e inclusive algunos que son palabras inventadas (como Mexicali). Así que generar nombres de municipios mexicanos *creibles* es un problema interesante.
#
# El archivo con el nombre de los municipios se encuentra para su descarga [aqui](municipios.txt).

# %% [markdown]
# ## 1. Redes recurrentes: Desarrollar una red recurrente completamente a pie.
#
# Con el fin de entender como funcionan las redes neuronales, vamos a aplicar un modelo de generación de texto *letra a letra*, en el cual tanto la arquitectura como el método de aprendizaje sean programados a mano.
#
# No vamos a pedir que lo programen todo solos, simplemente que utilicen el modelo programados en este [gist](https://gist.github.com/karpathy/d4dee566867f8291f086), y lo adapten a leer el nombre de los municipios y a generar nombres de municipios.
#
# Para esto:
#
# 1. Copiar el contenido del *gist* y comentarlo en español (y cambiar algo de código de forma que quede mñas claro para ti y para mi).
#
# 2. Copiar y comentar en español el contenido del método de verificción de gradiente (para limpiar el código de errores) y usarlo por unas cuantas iteraciones para demostrar que el algoritmo de entrenamiento funciona correctamente.
#
# 3. Ajustar los hiperparámetros del modelo, así como los parámetros del algoritmo de entrenamiento con el fin de generar una lista de nombres de municipios creibles, pero sin sobreaprendizaje (esto es, que copie vilmente el nombre de municipios existentes).

# %% [markdown]
# ### Librerias

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np
from random import uniform

# %% [markdown]
# ### Cargar datos

# %%
# data I/O
data = open('municipios.txt', 'r').read() # Lee el archivo que contiene las palabras a aprender
chars = list(set(data)) # Obtiene los diferentes caracteres usados
data_size, vocab_size = len(data), len(chars) # Tamaño del dataset y del vocabulario (diferentes letras que usan los municipios)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 35530 characters, 68 unique.

# %% [markdown]
# ### Función de perdida

# %%
def lossFun(inputs, targets, hprev):
    """
    Funcion de perdida
    
    Parámetros
    ----------
    inputs: número de entradas de la red
    targets: número de 
    hprev: 
    
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# ### Muestra de enteros del modelo

# %%
def sample(h, seed_ix, n):
    """ 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %% [markdown]
# ### Verificador de gradiente

# %%
# gradient checking
def gradCheck(inputs, target, hprev):
    global Wxh, Whh, Why, bh, by
    num_checks, delta = 10, 1e-5
    _, dWxh, dWhh, dWhy, dbh, dby, _ = lossFun(inputs, targets, hprev)
    for param,dparam,name in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], ['Wxh', 'Whh', 'Why', 'bh', 'by']):
        s0 = dparam.shape
        s1 = param.shape
        assert s0 == s1, 'Error dims dont match: %s and %s.' % (`s0`, `s1`)
        print(name)
        for i in range(num_checks):
            ri = int(uniform(0,param.size))
            # evaluate cost at [x + delta] and [x - delta]
            old_val = param.flat[ri]
            param.flat[ri] = old_val + delta
            cg0, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
            param.flat[ri] = old_val - delta
            cg1, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
            param.flat[ri] = old_val # reset old value for this parameter
            # fetch both numerical and analytic gradient
            grad_analytic = dparam.flat[ri]
            grad_numerical = (cg0 - cg1) / ( 2 * delta )
            rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
            print('%f, %f => %e ' % (grad_numerical, grad_analytic, rel_error))
            # rel_error should be on order of 1e-7 or less

# %% [markdown]
# ### Inicializar los parámetros del modelo

# %%
tol = 17

# hyperparameters
hidden_size = 38 # size of hidden layer of neurons
seq_length = 12 # number of steps to unroll the RNN for
learning_rate = 0.2

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %% [markdown]
# ### Main

# %%
while True:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = np.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    # sample from the model now and then
    if n % hidden_size == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print('----\n %s \n----' % (txt, ))

    # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % hidden_size == 0:
        print('iter %d, loss: %f' % (n, smooth_loss)) # print progress

    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter 
    if smooth_loss < tol:
        break
# Out:
# ----
#  ÑüdYOohiGifgn
# ZcOÁé
# is DFZ-aLzPqAL
# süázq.JÁ6JHJKGálvmhltRvxNVkjiMKñnL-
# büOcSfAHÑzOhEZIáCRH8NCH-vtnJphSv-MÑLyIfxdláutHfsm8RNK
# ii0kVPóSÑñbmFKbÑ-nY0dL.ZVD00MábHvvTgoJüR8PíNNqDdUéG.6dMTZHélf0JJEax,jCaUÁHG
# ----
# iter 0, loss: 50.634093
# ----
#  cuaAa
#
# abuu
# A
# AGulaeuaua
# Acua
# uu
#
# c
# A
# u
# Aguluuu n
# An
# AcurzcuAAAulaeueuaaaaul
# luuxalu
# leuuAlAAaAealuPA8uluubue
# lusAu
# Tuesbuu
# AaualAyauupAbu
# AguuPlPuuu
# aAbauAuueeuAeAuA
# A
# scu
# luAluPuabuu
# auuuuuA
# a uuAue
# ----
# iter 38, loss: 50.741284
# ----
#   Lala ia LtiArooLAlLe2tapectoaLíettucormctcLanehLtoeLloCrephtrdiLoiaatrtorLmcu uouaoaátue LPaAhDKtTLatidcoAoLddruoLeaoel  RAlostoA
# olaiRetyepiiLooacelPeomcocoérrmAl. oL
# AtlitrLdrr coe LopLetLttacLc y
# ----
# iter 76, loss: 50.321356
# ----
#  zaA
# Anazzol GiuaGdnnaaAÁjpápoa
# ppzpxao
# AgaGiÁlesoáhAng
# ApáplgloClanlalaxenpixae
# Apaxemaiacitlenaa
# Alap
# Anxan
# zn
# AnlrApaooAep n
# Angpeieclintersan eeanllxoeAhacetipzJx
# ApGe
# AprnzAn
# Alg ngtsá
# Ap
# Aniiaed
# ----
# iter 114, loss: 49.791548
# ----
#
# Aren   ecsBllíeno o non
# Anan oenuie B
# Amantplo
# Anceá
# Atil
# Atan ls
# Asanj sjecie ua
# Amen xe  loBanlíannapIpíogtee ieljííodaepácinj
# Amm
# ARtacallue
# Acetalácalán Tla mtm    Gan
# Arteye
# AyReeeaacee t
# An e
# ----
# iter 152, loss: 49.182645
# ----
#
# Auun
# Atua
# AjaRay
# AtopAyogayuy
# Ata
# AdonaacepapÁcan
# Atulanuehuuoiacapayayoyouo Tqaa
# Ayxaloyi
# Apaxo
# aíuyayualuo olahullaqala
# Ayooenacolc GTpe
# Ay ouoqorulnraa
# Aypljo va dáno
# Ayanoo
# Ato
# AlIdeyáqo
# Ayqoului
# ----
# iter 190, loss: 48.465880
# ----
#  lá esamo
# Bz
# Bo
# Banalazioo
# Beu loreáoaráb Beihoa
# Bastiíaáe Moa
# Buoáz
# Banapil Jelutae
# Bo
# iéoa oáin
# B Jíe
# Bee Toao
# Boodz
# Belío ioeyuo
# BerolomuoJuz detiemanlieai
# BeriAmán V
# Bri
# Balre Juariro ez
# zihmli
# Bá
# ----
# iter 228, loss: 47.838153
# ----
#  aagala  Csbnn
# Can
# n
# Canunalllbyralalogan
# CaeozniCaensOnre
# Canettaran
# CañepOróLanelngiZ
# Calanguanren dCan aanaTayian
# Cánañanananatexa
# Ceac
# Cenane
#
# enlTnal
# Cenanoangon CmalgZtienOCaniC
# CacanbblaeleagCa
# ----
# iter 266, loss: 47.246640
# ----
#  íaarsozdetlavan
# Cirilnzin
# C
# Cs
# Can igossn
# Cinttec
# tasin
# Can
# n
# Chita
# Cendasn
# CG
# rel
# Car
# CaPaedmincelzCa
# Can
# CMn
# Co úuan S
# iZtlri
# ián
# Chucachi
# n
# Cáscutnaíatn
# Carrndlo
# Cán
# Ce
# Can
# Cananh
# lasí
# Akonayo
# Cz C
# ----
# iter 304, loss: 46.592092
# ----
#  u
# Chmtincamáneri
# Chiiocáca dlelcultacán
# Chitoiciatpipoacon
# Chiiiánle
# Chico
# Chido
# Cticonocumo
# Chiient
# Chaooato
# Chiccalomiilcaatenoolcuacodelio
# Chicaámociiácciliouecoacicokonciican
# Chicopec
# Chicocuscoxt
# ----
# iter 342, loss: 45.769104
# ----
#  latepo
# CuuanciZn
# Clul
# ChumpilbáatoliGulngo rlán
# Chimaé
# C de ro Gía Ca
# ChCamhendiá Cliegise Básuelde di  de do di ánán Be Juimoétian dicányl
# Cimi liétes
# Chuihe
# C.go o
# Cbona
# rcueé de murlqxaslmamoangeru
# ----
# iter 380, loss: 45.056709
# ----
#  zllo
# Co
# lantllá xa
# CozderaluenmanFláe a len
# Cohuec ezéren
# Coi
# Chtilculcea
# Coa
# Cotzánte Gadcoven arinla delhontámatlehlo
# Caupes Fd couns
# BozcunancenhuiltldlcutejddoSlátzlán Capiónnlázás desatmuen lo
# uá
# ----
# iter 418, loss: 44.463575
# ----
#  Carandoaguulr do BoarCapán do alrlio
# Corigizrdáqaa de Cortla
# Coralaalñjaganln
# Coratófán
# Co deroro
# Ciayeqarrña
# Cañln de
# Copdnadlr Caróránpo Coga
# CopCzo
# Co di Mo
# Co toPan deloraz
# Cateteón Corsrloda
# Comi
# ----
# iter 456, loss: 43.830929
# ----
#
# Baranárátcealcuicántrimtélcarolán HeánMet de recia
# Cuóper Auttlamatcelrdexup dee H
# Ctepo.pe n
# Cotinu uimudu dc án
# CarHac denaceánsan
# Cuáán
# Cuotxrittadtmue dcán
# Carána
# Cápala
# C
# Cuan dR areti
# Bánargi d
# ----
# iter 494, loss: 43.165505
# ----
#  ec da pa I
# Cusazde Gce GIr zocel De Golála a Verán deo  Me de tonlo derver Vi cicromela De anciát
# Do
# sllo HCua  ár do D da
#  a a    m llál de der ir  Hocz alDl oro aViro Palzlla o de
# s aruo dez dez dn
# ----
# iter 532, loss: 42.681066
# ----
#  Laa Parril Gcqo Liqa Z
# Emrco
# El
# El Noos
# E
# AtnvarEl Bemortl  lo
# Elorelal
# El Er Orlararte Oolxrellanadsbrralra Jo
# Ere
# El erori A
# EríqumerúRdoro
# Erquo de Etor
# En de o
# EEnenle Oqula
# El
# Earipusmas
# El
# El A
# ----
# iter 570, loss: 42.242319
# ----
#  lo Ila Guco
# Fansb
# V FonorocorirFendo
# nre tavencodemoscaxncro Marer
# lopitlesyíololos
# Fmitrancil
# Ftápin
# Agonvaren denis
# ecricirasssqris
# OnoncarcaR Irlo
# Ar Mal
# Eren
# FopFa Izlacgilm
# ro Ihlenke ore
# Frcatpi
# ----
# iter 608, loss: 41.773402
# ----
#  Elo
# F Mto
# GenuenrreGórar G
# Gaqpérc Pines
# Gelánarel Tlenolirenl
# vía Elral GeliGoa Tel JreniGuíoherlalírel Leño
# Góperzrasoro
# G Geseralpel Eroel uesto órillil Tcodiv Golco
# CentreJíasaro Sele
# Genla
# eparo
# ----
# iter 646, loss: 41.310242
# ----
#  vz Zqterocuatsevadcetarór Fomdálatmu
# Gransíuz
# Gurero
# Gula vo Zuzvacu
# CuOzovo Hiodesul ororsar
# blza ibita
# Guder de
# Guepuaaramaraz Ztiz daz
# Goticlzra
# Gutitz
# Erogevireavavodacñeruz
# Guur
# GuimqGada
# Guto G
# ----
# iter 684, loss: 40.812579
# ----
#  apan
# BaRuntarintünlitndalobico
# Hunua
# Huajull
# HaeZoaxipapiila
# Htlantzapemo
# Hosgepalta HecuemaruaH.staro
# Huri Hepce
# Hunun
# Ho
# Holora
# Hanmo
# Puntagnasjelo
# HaniacameaneoMo
# Huéteruitac
# Gupimacuava
# Hadilapilc
# ----
# iter 722, loss: 40.417618
# ----
#  Hrepen
# Hun
# Hhúucolbtláp deH
# Huajpqtaymanjoc
# Humuxtlmo
# Hua
# Hudetlamo
# Huanmn
# Huatopelo
# Hoycotlénomanla des
# Huapas
# Hcaypotlpo
# Hrarpal
# Hupua
# Huiétlen
# Hirópa
# luaytúl Huapat
# Huiulelpaltláyoltlay
# Huagulelo
# R
# ----
# iter 760, loss: 39.784939
# ----
#  rexhhimi
# Ibehuádadca
# Ibuan
# Ilen
# Ixritthueco
# Huáheaápapixpetmato
# Iuas Suétlx
# IxyatléI
# Iguepec íuuxánmo
# Ipea ahajazpa
# Is Irex
# Ix Inpecupetex de tahHavuVa
# Inox
# Ixgchhtespadeda
# Ix deéhuatas de co de Itdeh
# ----
# iter 798, loss: 39.362858
# ----
#  rúremam Malila
# Izaraco
# Ilapitlán
# Fpa
# Ijoteacalarlasparza depuatla
# falac
# otatlán de de del MaRtotacoa Maciua Mas
# Ilaz de de JpinLahhhida Mas
# Iháadan
# daltlangillo
# Ixma
# Imavaréál da de Lechaprvl
# Ixtlatlc
# ----
# iter 836, loss: 38.793380
# ----
#  iitococes
# Jocles
# Jantetliren
# Jolcon
# Joato
# Jentlcacocincebez
# Japenco
# Jitten
# Joñcino
# JoxLalototlaclever
# Jocuác
# Nohuemectlcocon i
# Janaleco
# Juelan
# Jozas
# Jomanpepal
# Jotatecotíetepes Jo
# Jalal
# Jocanal
# Jrlanc
# ----
# iter 874, loss: 38.266512
# ----
#  Laigór Larí
# Na Glrha
# da
# da CasMatla
# Eluacrezo
# La Lhhald
# des
# LeRíaraguirhtas
# Landa
# da Catda
# La Lorhre
# Lactaéga
# da
# Cic Lco
# La Canlo Laco
# Lapal
# Lacmapi
# Lo Coda LhatLic
# Luncosparál
# Lhhen
# Lhuat Lidacca La
# ----
# iter 912, loss: 37.901548
# ----
#   Mole
# Laszanstzas
# Lasgán Mas
# La Has
# Las da Nor desns
# Lamas
# La Masisrdes MagarYaroz
# Laslacasriras
# Laltranapa Losrmrez orda de Mas
# Lacoss
# Lass
# La Muaras
# Ca Cadraspas
# La Mro Poguss
# La de
# Luas
# Lana
# Lasna
# ----
# iter 950, loss: 37.505331
# ----
#  maba
# Magas
# Hende Ma Mila
# TacdanaenaM
# Ma
# MTamontetrengo do
# Masteya
# Mas
# dasc
# Ma Mite
# Maguac
# Log
# tjriletlogMa Tegavepil Ma dec
# LagdanaamamraMa
# Manas Maysareda
# MaAdega MaguinagAl
# Mendeyomah
# te Mepara
# Mala
# ----
# iter 988, loss: 37.067875
# ----
#  totlen
# Mbetío
# Mahtililapapos CastatleocotoTuo Iedispa de dero
# Mavoasrenbopan
# Mántore ToíVotivatlaradale
# Magualca Matarscotmo
# Macuego dero Tíblotacen
# MartMatas
# Maptez de Tostoraas
# Martiran
# Matara Mo Tr
# ----
# iter 1026, loss: 36.687213
# ----
#  dec Oxqéuqeltlztepill Oimalz
# Matizotixran
# Meroxmo Cel Mempe
# Mooqulpex tedic
# Molben
# Molchren
# MeéApán F.tlán
# Mezmác
# Matilho
# Meuloqqiecone axc
# Melepizce de Mándepea de Delquleycoe de Fequilla
# Mazaxocallc
# ----
# iter 1064, loss: 36.253151
# ----
#  Mort
# Mis Meluixhaaca CáncoMomorRa
# caxsicontoatecha FhuanoyilNo Vomimoco
# Molan
# Menca Jaronoo
# Molas
# Meinoto
# Minotalabixa
# Miteco
# Mocdingo
# Mimhpán de Alaslál ororo
# Mualde
# Molo
# Modcicaca de Jagho Axanal oo
# ----
# iter 1102, loss: 35.864821
# ----
#  zho
# Nazdaatlezhuvta
# Nañal
# Nadepo
# Naa
# Naminán
# Nova
# Naataajara Na
# Na
# NavatidatlohuanNoren da
# Nas Na
# Naciláu
# Nantago
# Nuterjotlepaczas Nalavatl
# Nat
# Natcan
# NatloR
# NaNala
# Auaz Natlánda
# Napi Naoa Narilas
# Nav
# ----
# iter 1140, loss: 35.535118
# ----
#  mavomes
# Osdecomomepec
# Osgonan
# Oalán
# Ouapompámpo
# Ovon
# Ozánco
# Ovohom
# Omo Olcmpenlos Oravpcco
# OucamOpa Olmor
# OTcoxcacomo
# Ogumo
# Ovepa
# Opicam
# OmovoyOmtomán
# Ocomago
# Ozamto
# Oqulopapoz
# OOderas
# Operpra
# Oqpanpa
# ----
# iter 1178, loss: 35.212954
# ----
#  c
# Ptoci Phatca
# Paanán Peicaro
# Puata Pobáll
# Mi d. Ptexmen
# Puatolago
# Pucatahuanis
# depen Pazalán Pagueni
# Pueten
# Pacalác
# Peutlán
# Pomazaa
# Pacana
# Azcala Pmtlocatoc
# Betzil
# Poac
# Pocaa hueloPba
# Poalo
# Puatvaula
# ----
# iter 1216, loss: 34.922534
# ----
#  Pidilaririiritexama
# Pánacitocortititálquirotlco
# PimutPajo uotjueata
# Pesnán
# Pijino Atocaciariquo
# ocirlojahuararjmaís
# PladacolaPeriihoguiliimimadi
# Piosama
# Paruatibrelotecicijirico
# Piñacatejirixaacío
# dep
# ----
# iter 1254, loss: 34.625273
# ----
#  ertluo
# Purlero
# Efióre del Vantaxbariguinero
# Puebos
# Puemvo
# Puiérate íotlelc
# Puecuañac
# Guórto Es
# Guncuegguete Huilca
# PuArtláro
# Puecaa
# Pue PórguCan
# Puerarol Auerlas
# Puchsl
# Puequenré
# Puerueyuo
# Puereráno
# P
# ----
# iter 1292, loss: 34.344235
# ----
#  oro
# Sucbas S
# mamas
# O Gucarlandocoa
# Santigaa
# Azosa
# Saálaí
# SoAliya
# Saero
# Saydran
# Sarisahuórenachtigo
# Rua
# Sixrelallerisderurana
# Ririlanto Siccamiyanando
# Ríariíro
# SuGyirtan
# Sueres
# Sariqamos
# Pariogo
# Sazeri
# ----
# iter 1330, loss: 34.121338
# ----
#  de Aan Sumémen Ovis Atda Sal
# A Dmiri AgCriutas T. Acb xui Cuiro
# Fen Iadatltíra de Sin
# San Am AsEczos dé Anubranta
# Sas Axanla
# San
# Shuusinacle
# Salo
# Sun Sén Cuisitis Anuagas Buess
# Sanmo
# Sontirífan Atacan
# ----
# iter 1368, loss: 33.853612
# ----
#  AnSin  a
# Ainos Tal
# Sage Ca
# San
# Cona de ua
# Sinin Antén Caoto  otatipe
# Sati
# Sonto Bán Sénmo Cexa Anlo
# San Anbirita Aztan Acdaquñid
# Baros Cas da Can
# San  Schan
# Sanio Sénto Nál Calio Aidito Co Anto
# Amut
# ----
# iter 2128, loss: 26.568050
# ----
#  alarola Maxíía Míate Taría Moues O
# Santa María Oc
# Samola
# Santa Ñarua Zaría Charto dea Matío da
# Santa Juría Maro Gucerata María Macuida
# Santa Maríárola del Luaríha Griro María Raciralí
# Sabía lepapel de
# ----
# iter 2166, loss: 26.204671
# ----
#  ío Mocata Moariatepatgosaca Ago
# Santa Tartíe aqrala Tsrentzcularata
# Santa Nabío Míisrire epotoca Paso
# Santa Maqíamolotepalota Macoomoróna
# Santa Miría Nonta Qui
# Santa Ahuanlo Saja Otío de Zatía
# Satíqaa
# ----
# iter 2204, loss: 25.804004
# ----
#  cuilic
# Santa Maríatetl Regucavec
# Santa Zalootnápe
# Santa Sailaquagoero
# Santo Paguandeltaca
# Santa
# Santa Yacuiguata Riatogoxóvo
# Santa Nuilo
# Santozapia
# Sanata Acochao
# Santa MatiolirocZa Yogías
# Santa taYut
# ----
# iter 2242, loss: 25.414587
# ----
#  l
# Santiahíagiaxe Chiaxagamigopalago Laxetzago Juilaz
# Santiago Ladi
# Santeahuaxticayagogomíagola
# Santiagotlagocoaxilan
# Santiagilgacíalalacaraciigongl Lucacoiago Satacxag
# Acpalui
# Santiago del Lemguogovim
# ----
# iter 2280, loss: 25.089896
# ----
#  ragonMantaluagón TGatepeng
# Tpego Royogo
# Santilgilagorón
# Santiago Tzaxqilantil
# Santiigo Taxiigo Techogoma
# SantiánonGocuhelgo
# Santi
# Santihítlog
# Santiago Tenla
# SantiazAllitlanllingotipepa
# Santixla Tentia
# ----
# iter 2318, loss: 24.698024
# ----
#  anipec
# Santo Daninomo dec
# Santo Damepa
# Shqolgo Erago pemogo Dlánuhuileepitoghiante Dunon
# Santa Domer
# Santo Detonto Duan
# Santo Donqojo Dopen Peuropen Pixaago Jomgo Guco Docapepapenta Dioho Prmelgo Nanm
# ----
# iter 2356, loss: 24.459890
# ----
#  nto Ttogo Yomápetlánpastaca Taliocopezi Teoto
# Santo Csago Tolmos TrLacoyayláltepa Ta
# Tza
# Sagopal Tlago Timiughicogua del
# Santo Tlála
# Santa Nopas
# Santo Yomás
# Sango Tlálan
# San Reyos
# Santas
# Santues
# Santa
# ----
# iter 2394, loss: 24.192845
# ----
#  ado
# Sozpa
# Sua
# Sazepechuépáe da du Tomapa
# Soyan
# Soyipá
# Sama
# Solilhhilo
# Soais
# Sucan
# Sardo
# Su
# Sutlota Taadpe YodiYo Xacoaño
# Shipetlc
# Sacueta Rotepern
# Suioo Tisií
# Soyho
# Senánha
# Sacocoteá
# Sudepilbchilán
# Sh
# ----
# iter 2432, loss: 24.369008
# ----
#  da
# Taranva YaTatlampas
# Talandi de Tántadapa
# Tapucacachata
# Tanhuapa
# Tanpa
# Tancas
# Samonachichaana
# Yuzba
# Tatapac
# Tanza
# Thacamarílajachillal
# Tanbe
# Ayaqulocoagosha
# cananhoza
# Tanan
# Tayan Tepacacus Tapamasde
# ----
# iter 2470, loss: 24.467730
# ----
#  agustla Tel Ñxtalatantl saplaccopla
# Telo
# Tebrlacul
# Totela
# Telajamate
# Timomo Te Teteá
# Techobbo
# Tehanraztenda
# Te
# dec
# Telgoán Tratla Techacc
# Tecolepen Tes Telopeo de cantea de Temesvlpe
# Tinchas Jua
# de Te
# ----
# iter 2508, loss: 24.505220
# ----
#  nantlán de Moral
# Teaho
# Tertel Tolaarua
# Tenierconaten
# Teza
# Tancilo
# Teotoapeple
# Teltnán
# Teoyoloco Telanco icosgolos
# Teatecaliz Iyo
# Tehoszolgo
# Tengon
# Tenalan
# Tioro Teopols
# Terielta
# Teoko
# Tehuál
# Telaltiáa
# ----
# iter 2546, loss: 24.420578
# ----
#   de Mhzal
# Teme
# Tepen Vea
# Todel
# Tepeticu
# Tepe
# Tzpenala
# Texhoroschiande Telciltlca Xexpica dl  Jo
# Teohuultlmetecaadcac
# Tepe
# Tepatlán de Hopitepec de ddechi
# Temla de Maraltlpo
# Tepecayuitla
# Tejigotapetis
#
# ----
# iter 2584, loss: 24.350647
# ----
#  inancán
# Teaca
# Tetocancuixtián
# Tea
# Tea Tiacuintimasgunan
# So
# Tielohule
# Tunin Jualocuro Lanedo
# Tepul
# Tenhiscica
# Telcca
# Tiantlantlicélco
# Teonla
# Tipi
# Tacgosangán To Na
# Ticantepuaclc
# Teníca
# Tehantacaz
# Ticor
# ----
# iter 2622, loss: 24.336055
# ----
#  la
# Texhaltecurlo
# Talpaz de Olríelo Tlahal
# Thuacal
# Tapaldiypillem
# Tlah
# dei
# Resalalrec Lltlahuipdel Pumunca
# Tlahuechápedama
# Tiscuhuizílgulacma
# Tegono
# Teahues de
# Tlilco Textla
# TipBla
# Tetlpia
# Tevoán
# Tlán
#
# ----
# iter 2660, loss: 24.281263
# ----
#  zangotúcoan
# Tllancollanco
# Tlacana
# Tlaxuas
# Taxco
# Tlanánca Calida
# Tla
# Taxiquiguucac
# Mamo
# Tlaqua
# Tlaltajda
# Tamla
# Tayitláellantaxcag
# Tlalo
# Tlarío
# Tlacé
# Tlalaco de o
# Tlasola
# TlaMezban
# Tlanamama
# Tepinanpatl
# ----
# iter 2698, loss: 24.168162
# ----
#  mcilás de
# Tue Peyuivascla
# oucumuncom
# Tonlquililtlíutechel
# Tantiman
# Tlache Julu
# Tonde Zontlru
# Tgnec
# Temcuquilám
# Zulu
# Tlo dem mumen
# Teméncolimento
# Tunin de ío
# Tojulrez
# Totlayelc
# Tamula
# Totla Bultatlalát
# ----
# iter 2736, loss: 24.173262
# ----
#  appa Vaza delmac
# Trilá
# UrTlón
# Vridal RepDípa Varlepa
# Vogellla
# Valápohzila de Zleé Vaprlia de da Allpreltla de de Velú
# Vilanláe dC -vaz
# kádetlo de Morepid
# lalo
# Tulloco
# Vriónhuila
# de Vllríz de Gueledroo
# ----
# iter 2774, loss: 24.270822
# ----
#  gocuale de Cla Vila
# Volacavio di Calapa de Cazitlca de Gullan de Gullas de Ela
# Vilcangui
# Vilto
# Villa ds Cola dr
# Suo
# Villa Viatla
# VillaVa
# Vela Ala di de Miszuz de Alatapacanga
# Valaca Guilyalde la
# Vilda
# ----
# iter 2812, loss: 24.224637
# ----
#   Tetiópe
# Villa Vilóntin
# Villa Dlalialgo
# VialuViquiaciez
# Vizla Vilti Urechicié Vilapa
# Rolro
# Vell
# Viroo Vimza Villa
# Villa Polla
# Vila
# Viluora
# Violti Tlariepa
# Vilrón
# Vilico de Larral Huanaca Uila Villa Gi
# ----
# iter 2850, loss: 24.141836
# ----
#  n
# Xancuoccaco
# Valanaz
# Veltlán
# dandhialzam
# Xiacuepan
# Xaculánio
# Yincán de acopanán
# Tentechho
# U
# Xotlá
# Yaluvan
# Villa Gqahulra Gogíhelte
# Yacóe Yallascatlán
# Tepea Gachucoa Gagua io
# íhiópinddo lhoscior
# Yaman
# ----
# iter 2888, loss: 24.167024
# ----
#  n de Zoptapan de Gualepapis de Untotapedtlán de Zuapao Zisoya
# Zocuico
# Zantílá
# lána
# liolotépatrpo
# Zacapongehildán
# Vipodán
# Zagopan do Amspan
# Zaplán
# Zacatlán de derocaazocho Huátlán de Guitla Copa
# Zayula
# ----
# iter 2926, loss: 24.133868
# ----
#  onia de Goragoco Arala
# Acaa
# Oloo
# Altoroo
# Guapa
# Alamao
# Aldo
# Alalas
# Golanluoso
# Zapaso
# Vilcoscanjohuelpánfo
# dena
# de Culas
# Tladro
# Olán Axiobtlanano
# Cuda
# Tocoyuro
# Aotoo Aralo
# Vicaro
# Xogoco
# Socua Anugoo
# Zux
# ----
# iter 2964, loss: 24.224548
# ----
#  huero
# Atlán Ritial
# Acan
# Aniíu Achango
# Acgo
# Aciacetlaltepen Azltiáchilán
# Acaspeénlgiexlgo
# Canlalábaca Juirita
# Aluagute Tegulengonángán de uuetiatlan
# AluSo
# Acaalgai Antepe
# Ata uecote Juanoguigo
# Allacha
# ----
# iter 3002, loss: 24.227818
# ----
#
# Alarrepem
# Alezarodria
# Alajsmarogozas
# lamateriedo
# Alta Aljuzereya
# Artor
# Aktala Alacuáhiaptetazúra
# Alatlamea de Mlmredemiburulatla Huamotla
# Altlta
# Alenaehuarilarena
# Altz dellacoyamastzlyara
# Titzherritm
# ----
# iter 3040, loss: 24.243453
# ----
#  o de Alirapas
# Ahiecha de Ratikecayatiauper
# Antzatan Ixpangopan Imaro de
# Anutopun
# Amo Lattotla
# Atacbaeosiztinas
# Azbze Canguapavun
# Alalapen de Antotán
# Aztilo anéjangopen Bipaosoapan Juxcaso Ratro
# Amtalá
# ----
# iter 3078, loss: 24.293768
# ----
#  lcatiteó
# Acuez
# Atltetepen Anna
# Alpac Repan
# AliteántePe
# Apequactic
# Acráóratizo
# Arotepe
# Apitia
# Lostitlpen
# A
# Atucaielo
# Asitam
# Aren
# Andóo
# Acutiártera
# At
# Ánmute
# Anlotes
# Ascatesoy
# Asta Depec
# tinjeo del
# Arez
# ----
# iter 3116, loss: 24.383865
# ----
#  áztzcotua
# Atocanucomongui
# Anodopen
# Apam
# Atiba
# Atumuyreya
# Kzqurilgo Atotlás
# Atiyazgo
# Atsquintotelco
# Atlayalgosadulceiazacriya
# Atzancue Tuelgolio
# Atotechila
# Atlyóngo
# Artisac
# Atillo
# Atzilax
# Ayuanten
# Arah
# ----
# iter 3154, loss: 24.287349
# ----
#  tozipo Juzosománis
# Bintzan
# Beraso
# Bocen
# Berzilzo
# Benuze
# Bechiopimz
# Bohutlizlábed
# Barzixrotzán
# Bevitza
# Byareár
# Benta
# Beposábatomahia
# Berziro
# Blauteyo
# Bsánñenlo Jucoojo
# Bezáóc
# Botza derco
# Bacileren
# Blat
# ----
# iter 3192, loss: 24.385488
# ----
#  zola Orolas
# Caoxíhatancaala de Ceelinan
# Cachcaco
# Canden de Jamalanc
# lanco
# Canla
# Cateaisa Crnila
# Cliato Careran
# Aalonoxlangeo
# Casreeño
# Cancalilá
# Cazenomiiaso
# Canfánen
# Aruhangala
# Camfl
# Morulan
# Coñerác J
# ----
# iter 3230, loss: 24.449240
# ----
#  e
# Chiapondanga
# Cajotesutlchida
# Crenmos
# Cameldr
# Cacelchixringocapibkta
# Cátaspa
# langacúní
# Caloyxtlan oslpis
# Culláros
# Chpes
# Cas Cunoytel de Colistosceta de Cabitopa
# Canta Perliltlaho
# Cartlá
# Chtlelranghos
# ----
# iter 3268, loss: 24.519653
# ----
#  le
# Chiluán
# Chilco
# Chista
# Cholbalxngucutec
# Chilrima
# Comabu
# Choho
# Chilpi
# Chicezlilus
# Chingo
# Chilltape Guincuilpilvosca
# Chimuc
# Chazuca Celquéco
# Chioltonma
# Chimidu
# Chiccca
# Contlchic
# Chango
# Chicutlztexcuél
# ----
# iter 3306, loss: 24.412064
# ----
#  yango Juitapa tó Cangotlpapontlán
# Cárantlpan
# Chincuo
# Carllautus
# Cho Huxcun
# Cooloma
# Contla de Muca
# Chibmiémanimpan
# Chulucuidá
# Selamo
# Apanuo Cimabilcuartic
# Chillatec
# Chuitisotlá
# l
# Cilapentapes
# Chino
# Cem
# ----
# iter 3344, loss: 24.385409
# ----
#  n
# Canite Pecuel de Gonpo
# Czilán Coaljalustán
# Ca.ázan dildel Melioncaca
# Comalitihaticoca
# Czilinga
# Copilda
# Cottzasidiláp
# Árextlán
# Comal
# Cojínigas
# Chelqulitlalá
# Coendeca
# Coalo
# Cocostla
# Fuzosuatotoóco
# Che
# ----
# iter 3382, loss: 24.357556
# ----
#  iápeebáyo
# Coraecoaópacértoalo
# CodaneIlaraozeícoaco
# Codalal
# Cosolaaao da
# Conáo Bodquisaúo
# Celeldeca
# Coríorán
# Careo
# Coalán de Colalopalasoda
# Coarasiapisolago de
# Cangolza
# Comrocato lolacatrolaaaalotospo
#
# ----
# iter 3420, loss: 24.361250
# ----
#  uetezipla
# Cuécutla de Pituti
# Cuautzalilulátl de
# Cu
# Cuilindec
# Cuautziclinde Huéc
# Cuaca den
# Comuantatlán Áodés
# Cayus
# Cuduélétlanuxtlac
# Cuilatlán Cuamatlitla
# Cuatel
# ComacuCutitiaptzán
# Cuepapcijam Nujuatl
# ----
# iter 3458, loss: 24.316103
# ----
#  uáno
# Ocono
# Molfo
# Ocoso
# Mocez
# Oeganco Bv Ocoscoco
# Oáuéc
# Ocofcán
# Ocogo
# Atontác
# O
# Miramos
# Juarcacil Oto
# Fistobelgo
# Ocotez
# Opodro
# Momho
# Oacapán
# Opunmo
# Jomavo
# Dorarua
# Ovuápepen Delala
# Ococpam
# Mechacame
# Oco
# ----
# iter 4142, loss: 24.514252
# ----
#  ltaculmolpa
# OcaPlella
# Pilamac
# Pecra Capanca
# Dovutolunda
# Padan Rlatlán
# Pamuna
# Palutava
# Pantatelilas
# Páncava Atuvamapen de Juapca
# Nuarixalo
# Mahuá
# Igoczigucasla de Pante Párejacitlaz Rayacá
# Pimaro
# Baayar
# ----
# iter 4180, loss: 24.574303
# ----
#  cutaño
# Petmaban de Ball
# Pelapa
# Pencojilueui
# lolquichinca
# Prraldes
# Pislán
# Porpec
# PorUrío
# Pamuo
# Pánde de Can
# Pencaves de Aratiteta Ertnan
# Pispác
# Pizileta Arande
# Pálco
# Puerex
# Oayojia Jiáno
# Padabun
# Necho
#
# ----
# iter 4218, loss: 24.619457
# ----
#  orro Qour Qoarondamárrua Quamengo
# Plarariguejexicaporo
# Perilite de Qaiyadolro
# doncanistanoros
# Puenono
# Vestinutacoro
# Quarrenántas deoríu
# Prvaberoérera Querenmongánida
# Quehuehuetlarco
# Quanjorrononegho
# Q
# ----
# iter 4256, loss: 24.657753
# ----
#  rrinlpis de Rabri
# lirca Sarel Voscoma
# Sacastl Bafihull Rajian
# Sacanta
# Sanancán Escaro
# Sacas del diilrinarano
# Saruuíl Lónalo
# Ssontaala
# Suquécuara Buvrenés
# Sorosco
# Saxansareldel
# Samlegua
# Soscanlán
# Sonay
# ----
# iter 4294, loss: 24.724625
# ----
#  ulldr
# San AtéBés Crrintoz Apene de DaguCurac
# San Amagate Arésurtaréu
# Satlas de Bleral
# Sanarde Huerro
# San
# Marinos AsLas Silanca
# Sar Ditarémara Anitanes
# San Mérín Agumal AyuranorOr
# Sanruldéstlasta Giugd
# ----
# iter 4332, loss: 24.710551
# ----
#
# San An Anto Yoaútia di Juin Ahuquinca
# Aghuandaa AniAnahio Santo
# San Gua de Aláco
# Sonto
# Sunía
# San An An Areniira
# San Antogano Antío de Doo Vreguinio
# San Anditos
# Sanera
# San Lohuejo
# Lan Yosinata Huauqui
# ----
# iter 4370, loss: 24.475671
# ----
#  tare Yan Anta  Cosla
# San Yarcac
# San Viéxcuplo Yarro Sachiga
# Sanmos Yán
# Con Brla Sisperipo
# Sanuatepec Acralo CamonVerdo
# San Zaros
# San Bhopal Tamanihepo Tmo Colder
# San Bechueza Camtlto
# San Antono Yucani
# ----
# iter 4408, loss: 24.372368
# ----
#  pác Sal Fel Fhuelis Yengope
# San Balepemto Yindela
# San Lianfos de Selmo Feñlárehulchac Amis Fes Fepioril tapolo  diz
# San Saytega
# San Beyial Fémfal Laxtlánla
# Santollatines
# San Felapar
# San Jamares Nenuo
#
# ----
# iter 4446, loss: 24.312904
# ----
# Santa Marlo Titia Yatío Tapatiarono Aco Gauitepi
# Santa MatíAnta Zantzo Azuyo
# Sante Tapita
# ----
# iter 5206, loss: 20.794195
# ----
#  go Magora
# Santa
# Suntaa
# Santiasila Lalisso
# Santiago Calogotia Zadataá
# Yantia
# Santiamole
# Santiaxtipep
# Santialo Yacioro Lxcoago Coovohanito
# Santiago Coxtla
# Santilaza
# Santiago
# Santia
# Santiago Laálucanidep
# ----
# iter 5244, loss: 20.592559
# ----
#  Anlane
# Santa Santiago Magualotla
# Santiatepec
# Santiánepac
# Santiyxtlahé Taago Textepin Ficoreyoc
# Santialo Igualintla
# Santilaso
# Santapac
# Santiagtla
# Santiago Tendo Tlaago Celgo te úhiapel
# Santiagíó
# Santeá
# ----
# iter 5282, loss: 20.348188
# ----
#  m
# Santo Moco
# Santiagotisgu Jiogo Dumhoco Doxtepec
# Santa Dorepae
# Santa Anintilongo Zaxunto Zania
# Santo Comteco IDungo Tzango Tipingo Atinguizo Taminco oxto Doónosonotes
# Santo Dioda
# Santo Teninga
# Santim
# ----
# iter 5320, loss: 20.217528
# ----
#  anto Temtja
# Sactemeá Tucuengo
# Santixgo
# Sango Tentimlános
# Santo Tlmaelepec
# Santlán
# Santollo
# Sas Aco Tomatepoc depla
# Sants
# Sanchilás
# Santo Domcueyo
# San Romás Lofalas
# Santo
# Sango Nudin
# Santo Teoyas
# Santo
# ----
# iter 5358, loss: 20.140828
# ----
#  c
# Sulaipuz
# Sionoeco
# Sulatlpec
# Socucradho
# Santa azuilu
# Sulepee
# Salliaurpepa
# Sultlánahuo
# Saviár
# Sabjojál Dapal
# Silaplia
# Sayonac
# Saumo
# Suirhiirpe
# Saney
# Sullo Yocura Juálo
# Soyo
# Suelo
# Sayorec
# Sotag
# Soyuixc
# ----
# iter 5396, loss: 20.372536
# ----
#  a
# Tutepa
# Tachialolánlá
# Tacópalahuarpralalan
# Tamadá
# Tacantaroaro
# Tamaapatlán
# Morazanda
# Tanrolatlán
# Taranaqultatatlapa
# Tamrulalulca
# Tatzila
# Tasiláculpa
# Raadachiala
# Tabtaltepec
# Talentla
# Zanázanta
# Juuaxiu
# ----
# iter 5434, loss: 20.590145
# ----
#  emécapimodhicamana
# Tamamastepetlán del Pecuvuca
# Tecualcaepen de Morlaro
# Talgnaquegquatatzispen
# Techilanteá
# Tepaalatla
# Teruachiloz Asalallo
# Tajotpas
# Temcalquecamóc
# Tecalhilorringuacola
# Teca
# Tucachuelpe
# ----
# iter 5472, loss: 20.709309
# ----
#  e esampem
# Teoyogo de Gualiptepichu
# Tanlanca
# Tenán
# Temakonpa
# Tepeypepe
# Temertepec
# Temontepen de Egontaago Guixquepán
# Tentoghíeco
# Teestlpos
# Turuchatepin
# Tehingo cacó
# Tepacla
# Trá
# Temtítzontióno
# Tegocha
# T
# ----
# iter 5510, loss: 20.726466
# ----
#  Gejésrlca
# Tepulac
# Tetepatla
# Tehédrtepan
# Tepénco
# Tapees
# Teazalanto
# Tepipuaco
# Textla
# Tepchepaz
# Tepenmalldil
# Tepatla
# Tendele
# TeNopachriz
# Tlajotlaz
# Tepizdec
# Teozazoc
# Tepego de Mapatlán
# Tzdedzol
# Tepiat
# Tep
# ----
# iter 5548, loss: 20.699664
# ----
#  ac
# Tlala
# Tatlán
# Telantla
# Tuetetla
# Techun
# Tixlac
# Techando ulYuaca
# Tiagui
# Tica
# Terija
# Tío de Ogriltinc
# Tiíta de -arairo Panci
# Teaxieru
# Tepe
# Tecora
# Tíis di
# Tiloc
# Tlala de Bizínu
# Ti
# Ticabccinala
# Texca ono
# ----
# iter 5586, loss: 20.798086
# ----
#   Paxulgantla
# Toxrayac
# Titziaponpan
# Ixtaco Xlepee
# Tatzena
# Tlataper
# Tlaxcaninmo
# Tlángo Tepelpen
# Tláhilala
# Tlallatzotláná
# Tlingo
# Tulañaltopes
# Tizaña
# Tlánalgallinchel Vilallepa
# Tito
# Telechi Juilerta drix
#
# ----
# iter 5624, loss: 20.875158
# ----
#  opetlán
# Tacachocatco
# Tljotta
# Tecantocanc
# Tlaza
# Tetepec
# Ttlotxtec
# Téxtla
# Tlopec
# Tixtlá
# Tlatapano
# Temconoo
# Guirun
# Tlalanga Goconotac
# Tanco Roozitlpucila
# Tlaconco
# Timonje
# Tlazogo
# Tlala
# Timltlán
# Tamrintea
# ----
# iter 5662, loss: 20.847380
# ----
#  umuotlán
# Tuílil
# Manicoltepun de Zlína
# Totlalc
# Tomabca
# Tucuilte Vuepe
# Tuero
# Toxcoyunincalpec
# Tunuitla
# Tuxuo
# Tutapec
# Turon
# Tuxcec
# Tuátacoltlá
# Tumuco
# Tuacumcactico Villde
# Tucepec
# TultIm
# Textás
# Tusámpen
# T
# ----
# iter 5700, loss: 20.886872
# ----
#  la Vallahuel Vizlla Vilalan Vilápia de Velln
# Uoneza Villo Vella de Chouyaltilpirrecahzilal Temaxna de Jultla
# Virxo
# Vilera
# Vaatego Velánga
# Vallas
# Vilga Vualee
# Sallallepec A Vilas Vililan
# Valga
# Uazán de
# ----
# iter 5738, loss: 21.073400
# ----
#  zcilrel
# Sangare
# Va Prrtil de 2e Apalla de eusa
# Vumió Alasa
# Gunlpas
# Velaz
# Vimxca
# Vizaga de  Calde Zanadil de Miltlarde Jillua de Are
# Sola de Alalzan de Juilla
# nango de las rirraa
# Villa de ZepanVa de Pa
# ----
# iter 5776, loss: 21.072483
# ----
#  a Huayaldella
# Vilzacsan
# Vilasíntla Sumetlóncón
# Vilmanepee Vorlagrepiacintel Fío
# Vilixcilgasciogumallomanancualtlánoneetel dillarpa Villlereultiayartlahua
# Valvindrico
# Vilastlaldra
# Vilaziella
# Pllatlengo
# ----
# iter 5814, loss: 21.034419
# ----
#  ya
# Yalla
# Yajrataz de Vidtípa
# Telulantla
# Velcá
# Yualuatlán
# Yaraachee Ghengachipam
# imal
# Yayotlahec
# Tajade
# Yolen
# Yhhuchatla ZanUcochec
# Yaghare
# dohuea
# Yuxia Yotaca
# Yhirca
# Yatíe
# Yuláhichede
# Yatualedde
# Yaxca
# ----
# iter 5852, loss: 21.172739
# ----
#
# Zaputotepez de Áhucaldec
# Zlzigo
# Zanatlaca
# Zapantepec Pistepec
# Pixa de Coropan
# Zatlánga Zatotla
# Zapastilcopitlán de Muntepea
# Zapano
# Zatzipán
# da
# Zapaco
# Zapáhua del dala
# Yoyontiapet
# Zapentohuepen
# Zaptot
# ----
# iter 5890, loss: 21.182746
# ----
#  depello
# Acalan
# Zolere
# Vibaxtenpeso
# A
# Acolaca
# Vizdac de Axpascea
# Sobmamoma
# Xaxro
# Azan de Goro
# Arocareco
# Asoz
# Sordar
# Sobil de lasca
# Tasas
# Arastlasáuila
# dedec
# Ajucopán
# Acépac
# Soxtlán
# Aratlá
# Zazárasi
# Acua
# ----
# iter 5928, loss: 21.357123
# ----
#   Apacro
# Acul
# Agualaca
# Armalae
# Atlazallo
# Acicue
# Acua
# Acualeteá
# Ahuagajuialec
# Altzadatlánde Angmalta Amuiguaxtlán detoxhuinoola Cuacolcaloc
# Alumuiado
# Acuoluliza
# Abloldec
# Aruquedgo
# Azualas
# Azujatzahuo
# Al
# ----
# iter 5966, loss: 21.365644
# ----
#  co
# Aloramez
# Al Álgara Ozmala
# Azrertapen
# Acorosca
# Alcacomán
# Lorab
# Abulomas
# Acotlán
# Alzía de Álalideyan
# lojmerde Jumadde Jucaroralronpea Álcíarob
# Zuralla
# Alade
# Azacharxcadl Ango Alapacetro
# Azamamacen
# Ag
# ----
# iter 6004, loss: 21.467841
# ----
#  ucpoco
# Abamo
# Astlapab
# Apace
# Alocaco
# Ango
# Amlaporde Rraapan Abotepo go
# Amamos
# Acapan Ahuapona
# Apizo
# Ahuceco
# Acatlán Hipeto de Cuil Peruataca Agheal Apanepeyu
# Apaiépua
# Amroyano de Gotanoapáe
# Ametelco Co
# ----
# iter 6042, loss: 21.554484
# ----
#
# Atzángán
# Arón Acuetlán
# Acuelatipeca Pula Xoroyuayan de Juáncentejen
# Anotallca
# Alindo lo Uquel
# Axte
# Aticónco Papemantoma
# Azalde
# Altepaltielgohutiste Apaaucitel
# Ahuoc
# Atiteca
# Atlántuman
# Alanga
# Apia
# Are
# ----
# iter 6080, loss: 21.692726
# ----
#   de Áxtetez
# AcomoAl
# Atzaladpetzaza
# Ayello
# Ayazaurdecuntez Rzaxhuhzac Ajango da
# Atlzalen
# Ayulpoc
# A
# Ananca
# Ayoche
# Astíram
# Atlex
# Ayuinticacomom
# Atltoitedec
# Ayro Coctitilaqueopca
# Atzalomotoyca
# Atlticpan B
# ----
# iter 6118, loss: 21.686709
# ----
#  atis
# Buevolvo
# Binoterez
# Britilosi
# Buhiutlitopal Bapaque
# Bazizaz
# Buras Bebcayango
# Bulvo
# Angón de Birtinlán
# Bzodec
# Bonte
# Bebncas Bexninán Riejsca
# Buinco
# Bunatlán
# Buovevacilmaahuanotlán
# Bumica
# Bankitz de
# ----
# iter 6156, loss: 21.831138
# ----
#  ca
# Atlelán
# Cantigón Cajarerel
# Calananis
# Chlas Calties
# Cantilvo
# Canton
# Colila
# Capaélérepenla
# Bante
# Cayamacil de Gudrla
# Calziliñes
# Capuldeso de Jorasildek
# Asin
# Valicuñongucorac
# Cextopen
# Cangureziden.
# Ca
# ----
# iter 6194, loss: 21.974449
# ----
#  em  JCihkaro
# Can
# Chajcás
# Canchir Chinhuhhitel de Pilichihura
# Beñaso
# Cacho FChu
# Coltán de de
# Sazatlas
# Chin
# Chinla
# Chaljo
# Cotrol
# Coto Cerdago
# Calcasco
# Cayderto Arallsha
# Crrl
# Chastevar
# Cohomonchi
# Apulde
# ----
# iter 6232, loss: 22.070592
# ----
#  antixtlpa
# Chalto
# Culas
# Chicialz
# Chien
# Chachondolci
# Chihíma
# Chontez
# Chiculputon
# Chilasantenauda
# Chatholo
# Nuiuscu
# Chitaltlin
# Cheltétobamalo
# Chionkoninchhumango
# Chiitlcal
# Chitlla
# Chizhisco
# Chitaldua
# Chib
# ----
# iter 6270, loss: 22.037259
# ----
#
# Ciléntlán
# Cintimuco del Mitampez
# Cadtla de Huitlán
# Chipaós
# Celanza de Ocuépuindetzulul
# Ciñán
# Chupidprom
# Chayuamatepiditgo.
# Cománze
# Caditzo
# ded
# Viucitzontlchuutlán
# Corhuadcán
# del de Judutla
# Chiomedán
#
# ----
# iter 6308, loss: 22.074306
# ----
#  Costopilla
# Coaalohuepo
# Codaaltlán
# Comalco
# Compon
# Coliliatzos de Juaytos
# Cováz de Cotimo
# Coscamgotzitzqueco
# Carilistla
# Comatlán
# ColpiCepeco
# Coocax lomabéña
# Conaltzoxtlán
# Cototlu
# Ánmolmaccapac
# Coatlas
# C
# ----
# iter 6346, loss: 22.067365
# ----
#
# Copajás
# Catletza
# Cacala del
# Tlálal
# Cocamde
# Coruzapío
# Cuacoatlán
# Colas Cocon Cou
# Cogoayo
# Corimatoaco
# ColáneCantetono
# Cohue
# Cirendostetolito de dela
# Cocortes
# Coando
# Cenmala
# Colidecío
# Conas
# Caépár
# Colos
# ----
# iter 6384, loss: 22.099820
# ----
#  Citláo RBan depoc
# Coputsjetlzo
# Cumulcelu
# Cotimán
# Cuasca
# Costján
# Cuiyultisayen
# Cuakuta Churelalirimanlán de Nuia Jualdi
# Costlán
# Luostlán de Tlands
# CuPupa
# CuruteR Imucutlá
# Cutlamacuau
# Cuando
# Cualatlán d
# ----
# iter 6422, loss: 22.128697
# ----
#  umual
# Dzonda Bagumrem
# Dostos
# Iriepes
# Dirohuichí
# Diva
# Donóntlán Direpei
# Donroro
# Dopa
# Dos
# Sonca Gulrepam Defaliga
# Dilmakega
# Doxte Miyhilco
# Cuzarc
# Dulcaco
# Dedel Ficaracláh
# Doxna
# Duxma
# Dogumán
# Dumey
# Curo
# ----
# iter 6460, loss: 22.324546
# ----
#  Inamilo ón Hiñosxo del Vilizilomquinvo
# Elo lco
# Elgretlanallo
# Elalo
# Eosa
# Etlasorca
# Elán
# Elioaján
# Elconzán
# Elrínal
# Elcancoapánerindo Ura Eloo
# Elcilánidajuc
# Elanguatljo
# Aloo de Gaorosaquoracadil
# Etizanis
# ----
# iter 6498, loss: 22.451046
# ----
#
# Ebzarder
# Fogo Fenconl Ferama
# Frirc
# Frencin
# IEltávar
# Flarmamo Fracperu
# Micacoros de Zorloñero
# Fris Hilnan
# FDearo goscaco
# Atzava
# delo Uhuantle
# F. Veza
# Querrciol Fachonnan de Mechisfo Monoséo
# F. Fronaní
# ----
# iter 6536, loss: 22.601839
# ----
#  oralde
# Elalal Gereóí
# Gtila Pe.s
# Gelaza
# Gesroco Frallon
# Guerlatlá
# Al
# dela Zabja Co Flaza
# Gecetuc
# Erovil
# Guacón Geñle
# Geperín
# Gamase
# Ganaligelz l Frízos
# Giazrel
# Genlireso Nanuas Go Melales
# Gtarzilciaro
# ----
# iter 6574, loss: 22.739388
# ----
#  ón
# Gulílallo
# Tivarhuquitoa Guerildc
# F. Mjónde de Mirepada
# Gendarde
# Ellaapeo de Jíaha
# Güacomalcadal Guez Pazec
# Gueloécl Hísvebasa
# Gíodedetedác
# Vilaluacadrec
# Srzorel Zastepel Hreratla de Elélalalgochipa
# ----
# iter 6612, loss: 22.896565
# ----
#   Huabasde
# Hualas
# Doguar
# Huahuja
# Hui.la
# Huealán
# Huamataled
# Huimed
# Huazóni
# Huanasgo Huala
# Huamás Hustme
# Hoácers
# Cogio
# Huahiel
# Hudalas Hohía
# Hrada Homa
# Hemabed Huaatziz Joávehua de del Ridapalgo
# Huena
# Hi
# ----
# iter 6650, loss: 22.937417
# ----
#  Huazache
# Huamalgo
# Huitepho
# Heavitapáncualcuaca
# Huadán
# Huachiils
# u. Hucu
# Huihuaquispac
# Votiden de Huinli
# Huatla
# Huecacitlpac
# Huimayo
# Huajucanmaalte
# Hamuzl
# Huastapán
# Huáraca
# Huiyama del Himihuipal
# Huepa
# ----
# iter 6688, loss: 22.832686
# ----
#  pan
# Ixyaaxixman
# Ixntíel Iguepán Ixtlasaxtaca
# Ixquahuilfingápuma
# Ixcaldel
# Ixtlán Vicuiatranasquomáha
# Ixtes
# Ixparán de Irétlaxtedeala
# Ityutlabteman
# Ixitlmua Ixmaltlá
# Ixdexu
# Ismnadenga
# Susangen
# Ixtlalax
#
# ----
# iter 6726, loss: 22.866156
# ----
#   de Jodc
# Cámamatlatlán Jadodamatza Cáz
# Joslelco
# Muecpac
# Menampaso
# Julul del Río Hua
# Tepanlo
# Juéla de Juapan
# Cilla
# Judapec
# Ixtapetlán
# Juallca
# Ixtla
# Goltzán
# Julla
# Haldec
# lazamcoc
# Julaco
# Colalo
# Jullalald
# ----
# iter 6764, loss: 22.795772
# ----
#  ic
# Jojaro
# Jantqueresgo
# Jonon Japarobaxiaé da Jeoqué
# Jicrepez Jopécopé
# Jubié Fitztltegpen
# rilivzé
# Juan Jariso
# Jeanbaba
# Cosacohua
# quroqux Jonaréapo
# Ixtla
# Jiquizler
# Jayédisitlán
# Jozilto
# Jigoaco
# Jicie
# Jot
# ----
# iter 6802, loss: 22.803094
# ----
#  upacapua
# Lagulo
# Juhavo
# Jaánartepan
# Lúrtláh
# Lagtatlasidilbebaaloxcas Lapehuanco
# Cacaréla
# La Larlátenae Lo Frrlcilanasac
# Lo is deho delo de Lapanlancpen
# Grbltid de Lurénga
# Lrín La Pidel del LroyaguHara
# ----
# iter 6840, loss: 22.891574
# ----
#  opán
# Liramza Ayávánla del Rrate
# Lándrepen
# Laros La Rrarro
# Lápez
# Lahía da Lorraezo
# Larres de Raxos de Perros
# Las
# Landesca Lo Mestacoro
# Lagra Ladel Lacuitzaros
# Lu
# Larsaren Loreniris
# Lorlda da Sartlán de
# ----
# iter 6878, loss: 22.934247
# ----
#  adagenidelo Rasquidavo Minca Mognes Mietlarepe
# Velgdaca
# Lo Pesga
# Mes
# Moyago Pamapaco Dota dal Panoyán
# Malatoteras
# Maguso
# Qenazizaxzayatlán Magdán
# Madereli
# Luenangos Madreño Terepen
# Logdalo Zenlanazo
# G
# ----
# iter 6916, loss: 22.910596
# ----
#
# Mapenca
# Mantala
# Manux
# Mod
# Mromas
# MiOla
# MalMaza
# Mattara
# Macoro Chechil
# María
# Mandahuidutlán de Matlidadi
# Macaántlán de Tabeta
# Mapeitepac
# Masua
# Maxtaleópa
# Vamaza
# Artata Madeláhue
# Matasaribi
# Mayidatla d
# ----
# iter 6954, loss: 22.933892
# ----
#  n
# Mes de Corderen
# Maxtepec
# Memezo ez
# Mayándo Cpelco
# Mariquiero erizaretietez de Ocayde
# Metlán la Niyizga de Meadtenca
# Miza
# Motzita Míotli Chritlán de ilida pa
# Galefos Meziz Atiletlal
# Hecia
# Miquel Taqh
# ----
# iter 6992, loss: 22.951944
# ----
#  aévos
# Marroriro
# Mlamáo Molzorezos
# Merreoulecilcomon
# Menororeto
# Mogonemo
# Mhuloabolaha
# Moteron
# Monocon
# Molalla
# Morelepoyo
# Moracos
# Manuinoso
# Maroro
# Morecotomo
# Moña Cáránolo
# Mocelosas
# Monerelos
# Mexcas
# Oro
# ----
# iter 7030, loss: 22.887395
# ----
#  edetemalla Netlita Nayalangua
# Nehholarel Mqrejeelepiz
# N.lal
# Nartaldeltía
# Manetlár Arelitopa
# Natopacos
# Larxcatzzo delo de Rór Atla de Juitlal
# Rlaravexico
# Nutello
# Narepe Esalriralcinatz
# Nextepal
# Nantírl
# ----
# iter 7068, loss: 23.006647
# ----
#  s
# Nunaca Ocodolo
# Oachéro poomca de Mocávigo Ocuoses
# Lofía Olorca
# Ocisco
# Oralcopem
# Ocutlaco
# las desocax
# Opocpan
# Moól
# Juuco Gualoco
# Oúpen Zolahue Ocogo Oro
# Otlivontán Noqapa
# Opatexmoón
# Nucaczidí
# Joucefo
# ----
# iter 7106, loss: 23.025819
# ----
#  otlán
# Galutapec
# Madel
# Pedenamla
# Poscasto
# Pesta
# Tucarui
# Pbatlán
# Paxtlán
# Paraled
# Pobanal
# Phuata
# Pazapánla
# Paschitlán
# Satlán
# Pcánla
# Cho Raley
# Pavautlán
# Panpao
# Oontlahhon Posca
# Pcosga
# Ho
# Pásca
# Pcalloro
# Pa
# ----
# iter 7144, loss: 23.112138
# San Poslo de Juala Tranca
# San Jianca
# San Jobato Josciiloi
# Jojayo
# San Ixtlahuilán
# San Joanco Juana Cofón de José Juan
#
# ----
# iter 7524, loss: 22.466061
# ----
#  n Basucihuomil Becicutla Juaz Ayutlahuetlahua
# San de Buoco Bautlán Cliigheimro Jacila dezila
# San Joan Asutí
# San Rédatlán Baca
# San
# San Juan Dontepa Soñu
# San Luhuitzicatlán
# San Jhñatla
# San TuatiIpohuicu
# ----
# iter 7562, loss: 22.208479
# ----
#  an SanasgiCuitago Josla
# ...
# Vililaz
# Frazas
# Astó
# Villo de Olaril
# ----
# iter 35378, loss: 18.473026
# ----
#  uva
# Unoda la Viluilad
# Dzevas Villa Villana de Guerres de Hichialtepee
# Himaroz
# Villatla Tilapar
# Villana
# Villa Hide la Juanarziapaa
# Visego
# Villa
# Tulayanvina Julcolatla de Xajange Nuizaha
# Vieza
# Villa
# Vil
# ----
# iter 35416, loss: 18.453120
# ----
#  lucaldiapa Hlastepec
# Yolengo de Auziatl Yatamca
# Hichá
# Yaoltián
# Yuxcica
# Soltemac
# Yuchobió
# Yalcahú
# Vinetú
# Tilazucac
# Villchicán
# Xecondon
# Lorico
# Mazepe
# Yanótés
# Dirilo
# Cotatlán
# Yotanco
# Yáncuapan
# Tibate da
# ----
# iter 35454, loss: 18.617967
# ----
#  rláhpo
# Zapabella
# Atlápan
# Zapútla
# Zapexpanteá
# Buxcacáho
# Zacuiquitátaa
# Cotoloa Zerehuinchelán
# Zacahuahlán
# Sayado
# Zapatlán
# Zazlamda
# Zapripoz
# Zapatla de Zarma
# Zapechinapan
# Zapachiaca
# Zaconco del Viéstla
# V
# ----
# iter 35492, loss: 18.653658
# ----
#  apahuatlan
# Visla
# laya
# Perorepec
# Asalhía
# Zavarinico
# Zañobadic
# Asatzana
# Juladas
# Ahuetla
# Altín
# Estovaaho
# Jajho
# Pejongoo de Ampacango
# Zinabo de Zalpaslá
# Ahuajoz
# Acatez
# Zicamja Hedaletecior
# Zoxtesja
# Antez
#
# ----
# iter 35530, loss: 18.875094
# ----
#  tla Acutlán
# Aquatempay
# Acalgalpac
# Ancapanga
# Vitla Ahuetotitli
# Acuiz de Alicacoba
# Achilalco
# Aciapan
# Lonayayango
# Arucuta Antitláz
# Acanciscán
# Anchiapango
# Acatzon
# Ahuanago
# Amco Azuerub
# Ayitlán Alulidan
# Ah
# ----
# iter 35568, loss: 18.913206
# ----
#  ua de Mirín
# Ahuanoneza
# Aralcutla
# Rigréjomaloa
# Acone
# Alto de Egrimana
# Aciaqua
# Abomtapan de Áliloreo de Aldosude
# Amatzalgo Morudridac
# Ahuaman
# Amacongolocua
# Ahuelar
# Azacorarbáz Albas Alutarila
# Acamuca Cl
# ----
# iter 35606, loss: 19.062808
# ----
#  la
# Amtalo
# Abaza
# Amapo
# Sarsa
# Zatas
# Ahuaos yuariepan Copán Anomapeco
# Amalo
# Solcogo
# Agoreco de Ál Antepec
# Aqueba
# A
# Ancohue
# Ajatipan de Solcunal
# Alderua
# Altapo
# Antalán
# Amejaniz Amozoyac
# Anto Intlareo
# Ajal
# ----
# iter 35644, loss: 19.170154
# ----
#  risos
# Ajantisribab
# Ayutetel
# Azapanga
# Anxcatlán
# Atlára
# Ahales Guerranaguac
# Atejayanguigagatlángo de la Brero
# Atingo
# Anderitlán Atipeitlán
# Alocis
# Altetepec
# Ayitenez
# Yastepec
# Auculco Atalcotereo
# Asgoleri
# ----
# iter 35682, loss: 19.316223
# ----
#  liquorer
# Atuáraalo Dopa Zavires
# Asiquigo de Obmchiche
# Antangeta
# Ateyec
# Axiaxtlán
# Atzaltzaco xhuluaco de Áltelo Mixido
# Asmotalco de la Iguatla
# Atla
# Atlacus
# Ayadril
# Axtaterecs
# Apuiz Aguzatoto
# Aysinteca
#
# ----
# iter 35720, loss: 19.346793
# ----
#  o
# Bío Bucultimapo Guarpaco
# Butuzidiz Bunina Juánez
# Balitáz Beranto
# Tuayiltepec
# Brena
# Bato Beatzelatla
# Buóninas
# Bezeto
# Bahuateca
# Bauníz
# Bacomo
# Branganga Buzue Bezeazealo Misios
# Boconovixcalte
# Banutepen
# ----
# iter 35758, loss: 19.571252
# ----
#  náb
# Banuz
# Catempan
# Cangaliz de Borenga
# ChiCérca
# Codil
# Boncánta
# Goltoreca
# Coguacilalat
# Ceriolca
# Cobénalme
# Chara
# Ciar Catsata
# Calaman
# Cuhua -alantác
# Cotolo
# Caneo
# Tamrena
# Cayaciz
# Coanidar de Bandes Berbz
# ----
# iter 35796, loss: 19.776353
# ----
#
# Cormen
# Chisgo yanlez
# Cancaaltla
# Ziemhias
# Chatlán
# Banada
# Chén
# Chuché
# Casames de Rema
# Bés de Juárelaz
# Chilris
# Chalpa
# Berzande
# Caverra
# Chango Catlayán
# Cas Chuenda
# Canchinca
# Chache de Vigrandras
# Coliltes
# ----
# iter 35834, loss: 19.895942
# ----
#  o
# Chivono
# Chatlán
# Chilhiaz Cueltohuixhia
# Chochiár Rín
# Chantilla
# Chotenalo
# Chitoli
# Chixlida
# Cazih
# Chihuchilgritzár
# Chanpa
# Chipatepo
# Chirimpia
# Chanen
# Chimón
# Chorcan
# Chitipa
# Chicolta Cálitlán de Cuszuñe
#
# ----
# iter 35872, loss: 19.902115
# ----
#  de los Catíhuato de Chuáncuisdía
# Calchasco
# Céjuacacetz
# Chimán
# Cánco
# Camachisic
# Coymá
# CanCpa del Oro
# Cialápac
# Culinmaxmalcalcán
# Chilhuamán
# Cataltea
# CenCrchis
# Ciitlán
# Cióno
# Chobindamatla Gallicuca
# Chuot
# ----
# iter 35910, loss: 19.960389
# ----
#  chmio
# Cotos
# Comolte Cetarcaán
# Cartiatil Ciscoton
# Coanon
# Colpellis
# Colilo
# Trazziasinpan
# Coscamana
# Cominama
# Codápe
# Cudapa
# Coteo
# Cosgazatez
# Cuilos
# Coutzaque
# Chiran
# Chilama
# Codezpo
# Chodes
# Cángos Catocolco
# ----
# iter 35948, loss: 19.971201
# ----
#  ltes
# Corólultepájanca
# Cotzacotái lalcoparaao
# Conuma
# Cualcos de Cilalán
# Corcarcos
# Comenpanal
# Corisátla
# Conito
# Ocilgocoilco
# Coramapama
# Codo
# Cerunal
# Coxtla
# Cuada
# Comásteguila teapacumultlán
# Cadepo
# Cotío
# ----
# iter 35986, loss: 20.051843
# ----
#  atla
# Cucacás
# Calintlán de Cultlán Camantaca
# Cuixtlán
# Colalco
# Cuenpema
# Cuartiyzino
# Cospe
# Cuauchí
# Cancií
# Cuiló
# Cuauc
# Coéy
# Cozuatiapan
# Coxterús Cuataltepa
# Coalar
# Cuindatlán Hadrita
# Cóndec
# Cayomea
# Coloqui
# ----
# iter 36024, loss: 20.090224
# ----
#  ango
# Díoscua de Valco
# Dinerulco Cam Rolgora
# Dréngea Dulmis
# Direras
# Dterpa
# Coyuz Frenantic
# Dxpaldincis
# Corcultepec
# Cuango da de Bóno ecaveretla
# Buengeayancuem
# Cuanaltei
# Culos
# Cotzatlán
# Doguatla
# Denapin
# ----
# iter 36062, loss: 20.312823
# ----
#  l Peoón El Etzón Eszo
# Empezoz
# Elñimecia
# Escue
# El Excasila
# Elalez
# Etzámam
# Ela Ejosio E. Latira
# Escozo
# Sula
# Ucatlá fbzeo
# Eltzes de Tlalepa
# Elpen
# Ellaman
# At. Frayón
# Ellazitlán
# Elizma
# Elozatla Jolalzo
# Nio
# ----
# iter 36100, loss: 20.469746
# ----
#  rrima
# Frez Frentejana
# Arerrítinno
# Ejoya
# Cantlán
# Euchilco Ferriro
# Frarraro
# Puelte
# Maroluitlahuo
# Coniviz
# Fremaquisartepec
# Engo de Valzuyill Prrriz
# Esrurartepec
# Frantecan del Pertzi
# Yertepec
# Erenoto de J
# ----
# iter 36138, loss: 20.620126
# ----
#  osíra
# Grancoya
# Gonarren Alarilital
# Eára
# Gamrrór Zanalla Goxileya
# Fazún Bulilininatablás
# Genala
# Hieasaa
# Ganoaqua Gravime
# Gaérrengiaconlino
# Grésocaris
# Ganrxiyul
# Genazapa Gucantla
# Gonelal Gónracán de Gui
# ----
# iter 36176, loss: 20.736400
# ----
#  nahujue de Álaxho
# Gunemápá
# Doszerpaa
# Emodama Juatlán
# Genite Albrral
# Gumuciacac
# Guneradelpec
# Galsiva
# Gencuero
# Geríate
# Guadelli Zapetlání
# Dirrema
# Guartaco de Maledtepec
# Genacá
# Giarpa
# Hartancaala de Bend
# ----
# iter 36214, loss: 20.866424
# ----
#  a
# Huixo
# Yuuula
# Huatla
# Guélapenounat
# Hurcho
# Marayapo Huankizul
# Huadallo
# Estalalatla
# Humadán
# Huáretla Luisa
# Hua
# Huanouga de Hudañe
# Huatla
# Arinampianíl
# Hoizuncilzoncuauataetidos
# Huascapancébora
# Huilo Him
# ----
# iter 36252, loss: 20.920921
# ----
#  uez Magesches Radapa
# Gullohurhuuca
# Gaértorca
# Hucán
# Huechula
# Atzobalcinga
# Dokengo
# Huiyanat
# Huenlatla
# Hoza,no
# Huidasohua
# Hiiés
# Himende
# Hiechin
# Huihuimarpen
# Huá
# Huitlán
# Ayutla de Bundel de Hertago
# Hulild
# ----
# iter 36290, loss: 20.851106
# ----
#  dana del Salidatla
# Ixtzeraraaso
# Imiloz
# Ixhualotoral Herúndechela
# Ixcautla
# Huatla de Tumeme
# Ixzejatos
# Ixreapac
# Mololcastepec
# Ixtemonda
# Ikúnche Tlares Z. Lumón
# Ixcopín
# Izarrislohual
# Ixtlau Ixcayaca Hind
# ----
# iter 36328, loss: 20.910355
# ----
#  a
# Lala
# Felonde
# Jomra
# I. datlán de Martatlbo
# Jalporala
# Heraxhuigar
# Xoscilco de Sempal de Juáratla
# Hasquim de Láras
# Ixchalalpác
# Ipindrés
# Escuez
# Pengeo da Ocampa
# Gonarpad
# Ixcumal del PeSanilaco del Xagua
# ----
# iter 36366, loss: 20.825985
# ----
#  omaco
# Jiméngo de Juánoz
# Jinoren
# Jíato de Hesú
# Jocxtepec
# Ixtzo
# J. Sena
# Joqué
# Joltez
# José Faréd
# Soyalac
# Joles
# Jorongo Juaspa
# Joloco
# Ixter
# Jabaó
# Joycida
# Jolpas Menatiro
# Ixtlán
# Jecho Jaros
# Hianso
# Jométas
# ----
# iter 36404, loss: 20.812988
# ----
#   de Clalteá
# Cocuir. dó Ll Morres
# Naguzapac
# Laymas
# La Mantarancirla
# Lo Moneditla
# Latlán
# La Lotorre
# Lo IxtlaMecapec
# Jartitlayalla
# La Dincolpan
# La Crago de las
# Tuxtlán
# Zantolul
# Larínaala Hinulapo Crara
# L
# ----
# iter 36442, loss: 20.872904
# ----
#  La ditla Lbreca
# Laszas Pe quadán Cás de Ananatla
# Miril Zata
# Lasdanis
# Landeón Valas de La Lrasudez de Ixtziaza de Cosrena
# E lasasidas
# Lánorío
# LasFanapo de Codars
# Nulapa
# Lloras
# Cosdon
# Lar. de Án tadia
# L
# ----
# iter 36480, loss: 20.969484
# ----
#  rena Márdas Madarra
# Mananco
# Llajon
# Madivez
# Lusá
# Madeéseped
# Manalaa
# Lo Larinua
# Acavuz Canaqueto Jualpan
# Amren
# Anfo
# Modo
# Julitaltza drlacinga
# Maquicta del R. Marrauca al Mas Maldo
# Maguel Zajaluz
# Msatost
# ----
# iter 36518, loss: 20.976014
# ----
#   Mátepo
# Matsá
# Múmicar
# Maramidobla
# MalqaManteres
# Máso Martapan
# Morrio de Magómren
# Samitla
# Manténgo de lagonto
# Maghala
# Malchro
# Mares de Jerutlapa
# Muhuimatil
# Mapatlán
# Mamiapa Madepo Miompiga
# Mañapelo
# Mat
# ----
# iter 36556, loss: 21.026920
# ----
#  ingzas
# Magamel de Rrapa Tederez Melgolión
# Mizicá
# Metzingulcacul
# Mentalco Tlaric
# Meldeca
# Mantihuín de María de Madetemec
# Manez de Heayim
# Magtos de F. Undr Miguatla de Oexis Madúlgo
# Megte Oe Mácea María
# ----
# iter 36594, loss: 21.047311
# ----
#
# Marilco
# Momiatlán
# Muxi
# Mocalpan
# Morocuansido
# Méntel Mirgotonapes
# Monamtocitlán
# Vievo
# Moreento
# Mentoo
# Macuí
# Matororivar ulorío uruates
# Santa
# Matapa
# Santa María Tugustlán
# Sant Micaptado
# Santa Mabla del Perís Tlapala
# Santa María ulas
# ----
# iter 37734, loss: 17.732661
# ----
#  uava Cmiconcatla
# Santiaguagos
# Santiago Ata Doxigoán Atingehuay agoélala
# Santa María del Río
# Sante Mantepec
# Santo Merihtitintíár Tida
# Santiagdeca
# Santiterés Igpatepetla Huivisquixcencirec
# Santiagniida
#
# ----
# iter 37772, loss: 17.538482
# ----
#  o Harquisala
# Santualintia
# Santiagpac
# Santiago Axtalta María Miima
# Santimía
# Santiago Mauntignecán Tecó
# Santz Mineyalgo Mántepec
# Santiago Ajoz Xanza
# Santiaghiascalco
# Quicoltiilalti
# Santiago Zaióa Tucapi
# ----
# iter 37810, loss: 17.339074
# ----
#  urácho
# Santiago Tioxtepec
# Santiagnota
# Santiago
# Santiagpaí
# Santiagrepe
# Santiago Tlatlán
# Santo Crinfintapeca
# Santiago Setzalos Valzaldepe
# Santiago Ltzago Vicanxo
# Santiago Calo
# Santa
# Santiagne
# San Pedila
# ----
# iter 37848, loss: 17.147384
# ----
#  ilisco
# Santo Marío del Tío
# Sín
# Tanmintzigo Toto
# Santo Varto
# Santiagua
# Sante Díaapaago Conotolajo
# Santiago TepeyuPpat
# Santo Gapantlán
# Santo Domiela
# Sangomido
# Santiábana
# Santo Dovixtlán
# Santo Dogoroltep
# ----
# iter 37886, loss: 17.041917

# %% [markdown]
# ## Redes recurrentes tipo LSTM
#
# Las redes con unidades LSTM las vimos platicadas en clase, pero no hay nada mejor para entender un tema que implementarlo y comparar los resultados con la red recurrente simple, sin memoria, para esto vamos a hacer lo mismo que antes, pero con unidades LSTM.
#
# Para esto vamos a utilizar otro [gist](https://gist.github.com/karpathy/587454dc0146a6ae21fc) del mismo autor (que es una referencia obligada en el tema, por cierto). En este *gist*, el autor presenta un modelo de redes recurrentes LSTM desarrollado con *numpy* incluido el método de entrenamiento, pero no lo aplica a el modelado *letra a letra* como el gist pasado. Para esta parte de la libreta, lo que tienen que realizar es lo siguiente:
#
#
# 1. Copiar el contenido del *gist* y comentarlo en español (y cambiar algo de código de forma que quede mñas claro para ti y para mi).
#
# 2. Adaptar el modelo propuesto para usarlo en la generación de nombres de municipios.
#
# 3. Ajustar los hiperparámetros del modelo, así como los parámetros del algoritmo de entrenamiento con el fin de generar una lista de nombres de municipios creibles, pero sin sobreaprendizaje (esto es, que copie vilmente el nombre de municipios existentes).

# %% [markdown]
# ### Clase de LSTM

# %%
class LSTM:
    @staticmethod
    def init(input_size, hidden_size, fancy_forget_bias_init = 3):
        """ 
        Initialize parameters of the LSTM (both weights and biases in one matrix) 
        One might way to have a positive fancy_forget_bias_init number (e.g. maybe even up to 5, in some papers)
        """
        # +1 for the biases, which will be the first row of WLSTM
        WLSTM = np.random.randn(input_size + hidden_size + 1, 4 * hidden_size) / np.sqrt(input_size + hidden_size)
        WLSTM[0,:] = 0 # initialize biases to zero
        if fancy_forget_bias_init != 0:
            # forget gates get little bit negative bias initially to encourage them to be turned off
            # remember that due to Xavier initialization above, the raw output activations from gates before
            # nonlinearity are zero mean and on order of standard deviation ~1
            WLSTM[0,hidden_size:2*hidden_size] = fancy_forget_bias_init
        return WLSTM
  
    @staticmethod
    def forward(X, WLSTM, c0 = None, h0 = None):
        """
        X should be of shape (n,b,input_size), where n = length of sequence, b = batch size
        """
        n,b,input_size = X.shape
        d = int(WLSTM.shape[1]/4) # hidden size
        if c0 is None: c0 = np.zeros((b,d))
        if h0 is None: h0 = np.zeros((b,d))

        # Perform the LSTM forward pass with X as the input
        xphpb = WLSTM.shape[0] # x plus h plus bias, lol
        Hin = np.zeros((n, b, xphpb)) # input [1, xt, ht-1] to each tick of the LSTM
        Hout = np.zeros((n, b, d)) # hidden representation of the LSTM (gated cell content)
        IFOG = np.zeros((n, b, d * 4)) # input, forget, output, gate (IFOG)
        IFOGf = np.zeros((n, b, d * 4)) # after nonlinearity
        C = np.zeros((n, b, d)) # cell content
        Ct = np.zeros((n, b, d)) # tanh of cell content
        for t in range(n):
            # concat [x,h] as input to the LSTM
            prevh = Hout[t-1] if t > 0 else h0
            Hin[t,:,0] = 1 # bias
            Hin[t,:,1:input_size+1] = X[t]
            Hin[t,:,input_size+1:] = prevh
            # compute all gate activations. dots: (most work is this line)
            IFOG[t] = Hin[t].dot(WLSTM)
            # non-linearities
            IFOGf[t,:,:3*d] = 1.0/(1.0+np.exp(-IFOG[t,:,:3*d])) # sigmoids; these are the gates
            IFOGf[t,:,3*d:] = np.tanh(IFOG[t,:,3*d:]) # tanh
            # compute the cell activation
            prevc = C[t-1] if t > 0 else c0
            C[t] = IFOGf[t,:,:d] * IFOGf[t,:,3*d:] + IFOGf[t,:,d:2*d] * prevc
            Ct[t] = np.tanh(C[t])
            Hout[t] = IFOGf[t,:,2*d:3*d] * Ct[t]

        cache = {}
        cache['WLSTM'] = WLSTM
        cache['Hout'] = Hout
        cache['IFOGf'] = IFOGf
        cache['IFOG'] = IFOG
        cache['C'] = C
        cache['Ct'] = Ct
        cache['Hin'] = Hin
        cache['c0'] = c0
        cache['h0'] = h0

        # return C[t], as well so we can continue LSTM with prev state init if needed
        return Hout, C[t], Hout[t], cache

    @staticmethod
    def backward(dHout_in, cache, dcn = None, dhn = None): 

        WLSTM = cache['WLSTM']
        Hout = cache['Hout']
        IFOGf = cache['IFOGf']
        IFOG = cache['IFOG']
        C = cache['C']
        Ct = cache['Ct']
        Hin = cache['Hin']
        c0 = cache['c0']
        h0 = cache['h0']
        n,b,d = Hout.shape
        input_size = WLSTM.shape[0] - d - 1 # -1 due to bias

        # backprop the LSTM
        dIFOG = np.zeros(IFOG.shape)
        dIFOGf = np.zeros(IFOGf.shape)
        dWLSTM = np.zeros(WLSTM.shape)
        dHin = np.zeros(Hin.shape)
        dC = np.zeros(C.shape)
        dX = np.zeros((n,b,input_size))
        dh0 = np.zeros((b, d))
        dc0 = np.zeros((b, d))
        dHout = dHout_in.copy() # make a copy so we don't have any funny side effects
        if dcn is not None: dC[n-1] += dcn.copy() # carry over gradients from later
        if dhn is not None: dHout[n-1] += dhn.copy()
        for t in reversed(range(n)):

            tanhCt = Ct[t]
            dIFOGf[t,:,2*d:3*d] = tanhCt * dHout[t]
            # backprop tanh non-linearity first then continue backprop
            dC[t] += (1-tanhCt**2) * (IFOGf[t,:,2*d:3*d] * dHout[t])

            if t > 0:
                dIFOGf[t,:,d:2*d] = C[t-1] * dC[t]
                dC[t-1] += IFOGf[t,:,d:2*d] * dC[t]
            else:
                dIFOGf[t,:,d:2*d] = c0 * dC[t]
                dc0 = IFOGf[t,:,d:2*d] * dC[t]
                
            dIFOGf[t,:,:d] = IFOGf[t,:,3*d:] * dC[t]
            dIFOGf[t,:,3*d:] = IFOGf[t,:,:d] * dC[t]

            # backprop activation functions
            dIFOG[t,:,3*d:] = (1 - IFOGf[t,:,3*d:] ** 2) * dIFOGf[t,:,3*d:]
            y = IFOGf[t,:,:3*d]
            dIFOG[t,:,:3*d] = (y*(1.0-y)) * dIFOGf[t,:,:3*d]

            # backprop matrix multiply
            dWLSTM += np.dot(Hin[t].transpose(), dIFOG[t])
            dHin[t] = dIFOG[t].dot(WLSTM.transpose())

            # backprop the identity transforms into Hin
            dX[t] = dHin[t,:,1:input_size+1]
            if t > 0:
                dHout[t-1,:] += dHin[t,:,input_size+1:]
            else:
                dh0 += dHin[t,:,input_size+1:]

        return dX, dWLSTM, dc0, dh0

# %% [markdown]
# ### verificar emparejamiento secuenciales en batches

# %%
def checkSequentialMatchesBatch():
    """ check LSTM I/O forward/backward interactions """

    n,b,d = (5, 3, 4) # sequence length, batch size, hidden size
    input_size = 10
    WLSTM = LSTM.init(input_size, d) # input size, hidden size
    X = np.random.randn(n,b,input_size)
    h0 = np.random.randn(b,d)
    c0 = np.random.randn(b,d)

    # sequential forward
    cprev = c0
    hprev = h0
    caches = [{} for t in range(n)]
    Hcat = np.zeros((n,b,d))
    for t in range(n):
        xt = X[t:t+1]
        _, cprev, hprev, cache = LSTM.forward(xt, WLSTM, cprev, hprev)
        caches[t] = cache
        Hcat[t] = hprev

    # sanity check: perform batch forward to check that we get the same thing
    H, _, _, batch_cache = LSTM.forward(X, WLSTM, c0, h0)
    assert np.allclose(H, Hcat), 'Sequential and Batch forward don''t match!'

    # eval loss
    wrand = np.random.randn(*Hcat.shape)
    loss = np.sum(Hcat * wrand)
    dH = wrand

    # get the batched version gradients
    BdX, BdWLSTM, Bdc0, Bdh0 = LSTM.backward(dH, batch_cache)

    # now perform sequential backward
    dX = np.zeros_like(X)
    dWLSTM = np.zeros_like(WLSTM)
    dc0 = np.zeros_like(c0)
    dh0 = np.zeros_like(h0)
    dcnext = None
    dhnext = None
    for t in reversed(range(n)):
        dht = dH[t].reshape(1, b, d)
        dx, dWLSTMt, dcprev, dhprev = LSTM.backward(dht, caches[t], dcnext, dhnext)
        dhnext = dhprev
        dcnext = dcprev

        dWLSTM += dWLSTMt # accumulate LSTM gradient
        dX[t] = dx[0]
        if t == 0:
            dc0 = dcprev
            dh0 = dhprev

    # and make sure the gradients match
    print('Making sure batched version agrees with sequential version: (should all be True)')
    print(np.allclose(BdX, dX))
    print(np.allclose(BdWLSTM, dWLSTM))
    print(np.allclose(Bdc0, dc0))
    print(np.allclose(Bdh0, dh0))

# %% [markdown]
# ### Verificar gradiente en batches

# %%
def checkBatchGradient():
    """ check that the batch gradient is correct """

    # lets gradient check this beast
    n,b,d = (5, 3, 4) # sequence length, batch size, hidden size
    input_size = 10
    WLSTM = LSTM.init(input_size, d) # input size, hidden size
    X = np.random.randn(n,b,input_size)
    h0 = np.random.randn(b,d)
    c0 = np.random.randn(b,d)

    # batch forward backward
    H, Ct, Ht, cache = LSTM.forward(X, WLSTM, c0, h0)
    wrand = np.random.randn(*H.shape)
    loss = np.sum(H * wrand) # weighted sum is a nice hash to use I think
    dH = wrand
    dX, dWLSTM, dc0, dh0 = LSTM.backward(dH, cache)

    def fwd():
        h,_,_,_ = LSTM.forward(X, WLSTM, c0, h0)
        return np.sum(h * wrand)

    # now gradient check all
    delta = 1e-5
    rel_error_thr_warning = 1e-2
    rel_error_thr_error = 1
    tocheck = [X, WLSTM, c0, h0]
    grads_analytic = [dX, dWLSTM, dc0, dh0]
    names = ['X', 'WLSTM', 'c0', 'h0']
    for j in range(len(tocheck)):
        mat = tocheck[j]
        dmat = grads_analytic[j]
        name = names[j]
        # gradcheck
        for i in range(mat.size):
            old_val = mat.flat[i]
            mat.flat[i] = old_val + delta
            loss0 = fwd()
            mat.flat[i] = old_val - delta
            loss1 = fwd()
            mat.flat[i] = old_val

            grad_analytic = dmat.flat[i]
            grad_numerical = (loss0 - loss1) / (2 * delta)

            if grad_numerical == 0 and grad_analytic == 0:
                rel_error = 0 # both are zero, OK.
                status = 'OK'
            elif abs(grad_numerical) < 1e-7 and abs(grad_analytic) < 1e-7:
                rel_error = 0 # not enough precision to check this
                status = 'VAL SMALL WARNING'
            else:
                rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
                status = 'OK'
                if rel_error > rel_error_thr_warning: status = 'WARNING'
                if rel_error > rel_error_thr_error: status = '!!!!! NOTOK'

        # print stats
        print('%s checking param %s index %s (val = %+8f), analytic = %+8f, numerical = %+8f, relative error = %+8f' \
              % (status, name, 'np.unravel_index(i, mat.shape)', old_val, grad_analytic, grad_numerical, rel_error))

# %% [markdown]
# ### Main

# %%
tol = 17

# hyperparameters
hidden_size = 38 # size of hidden layer of neurons
seq_length = 12 # number of steps to unroll the RNN for
learning_rate = 0.2

# lets gradient check this beast
    n,b,d = (5, hidden_size) # sequence length, batch size, hidden size
    input_size = 10
WLSTM = LSTM.init(input_size, d) # input size, hidden size

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
# Out:
# every line should start with OK. Have a nice day!

# %% [markdown]
# Por último, agrega en esta misma celda comentarios sobre la comparación entre los dos modelos vistos, diferencias, similitudes, ventajas, desventajas. Recuerda es una opinión personal basada en tu trabajo, no pongas lo que dice la literatura si no lo que tu experimentaste a la hora de desarrollar y aplicar los modelos, así no concuerde con lo que leas en otros lados.
